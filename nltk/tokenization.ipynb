# %%
corpus="""welcome to learning of nlp.
i learn it from scartch
"""

# %% [markdown]
# tokenization

# %%
#sctence---->pargraph
from nltk.tokenize import sent_tokenize
documnets=sent_tokenize(corpus)

# %%
type(documnets)
# Out:
# list

# %%
# sentemce---->words
from nltk.tokenize import word_tokenize,wordpunct_tokenize
word_tokenize(corpus)
# Out:
# ['welcome',
#  'to',
#  'learning',
#  'of',
#  'nlp',
#  '.',
#  'i',
#  'learn',
#  'it',
#  'from',
#  'scartch']

# %%
wordpunct_tokenize(corpus)
# Out:
# ['welcome',
#  'to',
#  'learning',
#  'of',
#  'nlp',
#  '.',
#  'i',
#  'learn',
#  'it',
#  'from',
#  'scartch']
