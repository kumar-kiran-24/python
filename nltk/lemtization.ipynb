# %% [markdown]
# # word net lemmatizer

# %% [markdown]
#   lemmitaztion is the teqchique like stemming . the output we will get after limmatization is called lemma which is root word rather thar stem word

# %% [markdown]
# using the ditiocnary and serch the word in there

# %%
from nltk.stem import WordNetLemmatizer
lem=WordNetLemmatizer()

# %% [markdown]
# pos
#
# verb=v
# adjective =a
# adverb=r
# Noun=n

# %%
lem.lemmatize("going",pos="v")
# Out:
# 'go'

# %%
words=["eat","eating","eaten","writes","writr","writting","programmig","programs"]

# %%
for word in words:
    print(word+"----"+lem.lemmatize(word,pos="v"))
# Out:
# eat----eat
# eating----eat
# eaten----eat
# writes----write
# writr----writr
# writting----writting
# programmig----programmig
# programs----program

# %%
# !pip install gensin
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for gensin: filename=gensin-5-py3-none-any.whl size=1804 sha256=3691e4d930b62d6dae0b340dd4402e070d7eeaa7db7673026297c48e0b391d16
#   Stored in directory: c:\users\kiran\appdata\local\pip\cache\wheels\76\01\2c\b90bbcc116d1d3e2a51ad5610cba43f3e80fecb83db1bca3d5
# Successfully built gensin
# ...
#   DEPRECATION: Building 'gensin' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'gensin'. Discussion can be found at https://github.com/pypa/pip/issues/6334
